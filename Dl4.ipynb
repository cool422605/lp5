# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/Google_Stock_Price_Train.csv')

# %%
train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_set=train.iloc[:,1:2].values

# %%
training_set
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set_scaled.shape
# Out:
# (1258, 1)

# %%
X_train=[]
y_train=[]
for i in range(60,1258):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
#reshape it to (batche_size(#size of inputs),timesteps,input_dimension)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (1198, 60, 1)

# %%
regressor=Sequential()

# %%
regressor.add(LSTM(units=100,return_sequences=True,input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.4))

# %%
regressor.add(LSTM(units=100,return_sequences=True))
regressor.add(Dropout(0.6))

# %%
regressor.add(LSTM(units=100,return_sequences=True))
regressor.add(Dropout(0.6))

# %%
regressor.add(LSTM(units=100))
regressor.add(Dropout(0.4))

# %%
regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
regressor.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 19s 219ms/step - loss: 0.0333
# Epoch 2/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0085
# Epoch 3/100
# 38/38 [==============================] - 10s 258ms/step - loss: 0.0073
# Epoch 4/100
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0069
# Epoch 5/100
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0066
# Epoch 6/100
# 38/38 [==============================] - 9s 243ms/step - loss: 0.0078
# Epoch 7/100
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0061
# Epoch 8/100
# 38/38 [==============================] - 15s 388ms/step - loss: 0.0057
# Epoch 9/100
# 38/38 [==============================] - 11s 282ms/step - loss: 0.0047
# Epoch 10/100
# 38/38 [==============================] - 9s 233ms/step - loss: 0.0047
# Epoch 11/100
# 38/38 [==============================] - 10s 255ms/step - loss: 0.0050
# Epoch 12/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0056
# Epoch 13/100
# 38/38 [==============================] - 8s 218ms/step - loss: 0.0061
# Epoch 14/100
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0047
# Epoch 15/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0056
# Epoch 16/100
# 38/38 [==============================] - 8s 218ms/step - loss: 0.0042
# Epoch 17/100
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0044
# Epoch 18/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0047
# Epoch 19/100
# 38/38 [==============================] - 9s 244ms/step - loss: 0.0041
# Epoch 20/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0043
# Epoch 21/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0042
# Epoch 22/100
# 38/38 [==============================] - 8s 217ms/step - loss: 0.0040
# Epoch 23/100
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0041
# Epoch 24/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0038
# Epoch 25/100
# 38/38 [==============================] - 8s 219ms/step - loss: 0.0040
# Epoch 26/100
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0037
# Epoch 27/100
# 38/38 [==============================] - 10s 267ms/step - loss: 0.0039
# Epoch 28/100
# 38/38 [==============================] - 9s 226ms/step - loss: 0.0035
# Epoch 29/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0040
# Epoch 30/100
# 38/38 [==============================] - 9s 248ms/step - loss: 0.0037
# Epoch 31/100
# 38/38 [==============================] - 9s 239ms/step - loss: 0.0036
# Epoch 32/100
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0035
# Epoch 33/100
# 38/38 [==============================] - 9s 243ms/step - loss: 0.0036
# Epoch 34/100
# 38/38 [==============================] - 10s 248ms/step - loss: 0.0038
# Epoch 35/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0035
# Epoch 36/100
# 38/38 [==============================] - 8s 222ms/step - loss: 0.0033
# Epoch 37/100
# 38/38 [==============================] - 11s 279ms/step - loss: 0.0032
# Epoch 38/100
# 38/38 [==============================] - 12s 324ms/step - loss: 0.0030
# Epoch 39/100
# 38/38 [==============================] - 9s 243ms/step - loss: 0.0031
# Epoch 40/100
# 38/38 [==============================] - 10s 253ms/step - loss: 0.0032
# Epoch 41/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0037
# Epoch 42/100
# 38/38 [==============================] - 9s 231ms/step - loss: 0.0032
# Epoch 43/100
# 38/38 [==============================] - 10s 260ms/step - loss: 0.0030
# Epoch 44/100
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0034
# Epoch 45/100
# 38/38 [==============================] - 8s 219ms/step - loss: 0.0031
# Epoch 46/100
# 38/38 [==============================] - 10s 270ms/step - loss: 0.0030
# Epoch 47/100
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0030
# Epoch 48/100
# 38/38 [==============================] - 8s 217ms/step - loss: 0.0031
# Epoch 49/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0032
# Epoch 50/100
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0030
# Epoch 51/100
# 38/38 [==============================] - 8s 223ms/step - loss: 0.0025
# Epoch 52/100
# 38/38 [==============================] - 11s 278ms/step - loss: 0.0026
# Epoch 53/100
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0030
# Epoch 54/100
# 38/38 [==============================] - 8s 220ms/step - loss: 0.0026
# Epoch 55/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0034
# Epoch 56/100
# 38/38 [==============================] - 10s 267ms/step - loss: 0.0033
# Epoch 57/100
# 38/38 [==============================] - 9s 225ms/step - loss: 0.0028
# Epoch 58/100
# 38/38 [==============================] - 11s 278ms/step - loss: 0.0027
# Epoch 59/100
# 38/38 [==============================] - 10s 262ms/step - loss: 0.0030
# Epoch 60/100
# 38/38 [==============================] - 9s 232ms/step - loss: 0.0029
# Epoch 61/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0025
# Epoch 62/100
# 38/38 [==============================] - 10s 253ms/step - loss: 0.0026
# Epoch 63/100
# 38/38 [==============================] - 9s 241ms/step - loss: 0.0024
# Epoch 64/100
# 38/38 [==============================] - 11s 278ms/step - loss: 0.0025
# Epoch 65/100
# 38/38 [==============================] - 9s 246ms/step - loss: 0.0026
# Epoch 66/100
# 38/38 [==============================] - 10s 248ms/step - loss: 0.0026
# Epoch 67/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0023
# Epoch 68/100
# 38/38 [==============================] - 9s 238ms/step - loss: 0.0024
# Epoch 69/100
# 38/38 [==============================] - 10s 259ms/step - loss: 0.0022
# Epoch 70/100
# 38/38 [==============================] - 11s 282ms/step - loss: 0.0023
# Epoch 71/100
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0024
# Epoch 72/100
# 38/38 [==============================] - 10s 264ms/step - loss: 0.0024
# Epoch 73/100
# 38/38 [==============================] - 10s 277ms/step - loss: 0.0022
# Epoch 74/100
# 38/38 [==============================] - 8s 222ms/step - loss: 0.0023
# Epoch 75/100
# 38/38 [==============================] - 10s 269ms/step - loss: 0.0024
# Epoch 76/100
# 38/38 [==============================] - 11s 279ms/step - loss: 0.0023
# Epoch 77/100
# 38/38 [==============================] - 8s 221ms/step - loss: 0.0023
# Epoch 78/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0023
# Epoch 79/100
# 38/38 [==============================] - 10s 277ms/step - loss: 0.0023
# Epoch 80/100
# 38/38 [==============================] - 8s 220ms/step - loss: 0.0026
# Epoch 81/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0021
# Epoch 82/100
# 38/38 [==============================] - 10s 278ms/step - loss: 0.0022
# Epoch 83/100
# 38/38 [==============================] - 8s 223ms/step - loss: 0.0022
# Epoch 84/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0021
# Epoch 85/100
# 38/38 [==============================] - 10s 266ms/step - loss: 0.0021
# Epoch 86/100
# 38/38 [==============================] - 9s 223ms/step - loss: 0.0021
# Epoch 87/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0022
# Epoch 88/100
# 38/38 [==============================] - 10s 254ms/step - loss: 0.0021
# Epoch 89/100
# 38/38 [==============================] - 9s 237ms/step - loss: 0.0020
# Epoch 90/100
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0021
# Epoch 91/100
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0021
# Epoch 92/100
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0020
# Epoch 93/100
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0021
# Epoch 94/100
# 38/38 [==============================] - 9s 234ms/step - loss: 0.0020
# Epoch 95/100
# 38/38 [==============================] - 10s 257ms/step - loss: 0.0021
# Epoch 96/100
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0018
# Epoch 97/100
# 38/38 [==============================] - 8s 223ms/step - loss: 0.0017
# Epoch 98/100
# 38/38 [==============================] - 10s 269ms/step - loss: 0.0020
# Epoch 99/100
# 38/38 [==============================] - 10s 276ms/step - loss: 0.0017
# Epoch 100/100
# 38/38 [==============================] - 12s 312ms/step - loss: 0.0021

# %%
test = pd.read_csv('/content/drive/MyDrive/Google_Stock_Price_Test.csv')
real_stock_price = test.iloc[:, 1:2].values
total_data=pd.concat([train['Open'],test['Open']],axis=0)

# %%
inputs=total_data[len(train)-len(test)-60:].values
inputs=inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
X_test=[]
for i in range(60,80):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)
X_test.shape
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
predicted_stock_price=regressor.predict(X_test)
predicted_stock_price=sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#Visualization
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(predicted_stock_price,color='red',label='Predicted Stock Price')
plt.plot(real_stock_price,color='blue',label='Real Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
